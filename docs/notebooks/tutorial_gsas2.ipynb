# %% [markdown]
# # Finding the starting lattice parameters using GSAS-II
#
# In the prior tutorial, we found the starting lattice parameters using MILK.
# We can also use other Rietveld packages such as GSAS-II.
#
# In this additional notebook we will find the starting lattice parameters using GSAS-II.
#
# **Note, this example uses the lead sulphate data data found here: https://github.com/lanl/spotlight/tree/master/examples/lead_sulphate**
#
# **If running the notebook, you need to copy the data files to the directory you run the notebook.**
#
# **Note, this notebook was tested using GSAS-II revision r5609.**

# %% [markdown]
# # Define cost function
#
# We define the following cost function that sets up the lead sulphate example from the GSAS-II tutorial.

# %%
import GSASIIscriptable as gsasii
import GSASIIlattice as lattice
import io
import multiprocess
import os
import shutil
import sys
import time
from mystic import models
from spotlight import filesystem

class CostFunction(models.AbstractFunction):
    
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        
        # if True then create the subdir and copy data files there
        self.initialized = False
        
        # if True then print GSAS-II output
        self.debug = False
    
        # define a list of detectors
        self.detectors = [dict(data_file="./PBSO4.xra",
                               detector_file="./INST_XRY.prm",
                              min_two_theta=16.0,
                              max_two_theta=158.4),
                         dict(data_file="./PBSO4.cwn",
                              detector_file="./inst_d1a.prm",
                              min_two_theta=19.0,
                              max_two_theta=153.0)]

        # define a list of phases
        self.phases = [dict(phase_file="./PbSO4-Wyckoff.cif",
                            phase_label="PBSO4")]
    
    def function(self, p):

        # get start time of this step for stdout
        t0 = time.time()
        
        # create run dir
        dir_name = f"opt_{multiprocess.current_process().name}"
        if not self.initialized:
            filesystem.mkdir(dir_name)
            for detector in self.detectors:
                filesystem.cp([detector["data_file"], detector["detector_file"]], dest=dir_name)
            for phase in self.phases:
                filesystem.cp([phase["phase_file"]], dest=dir_name)
            self.initialized = True
                
        # create a text trap and redirect stdout
        # this is just to make the stdout easier to follow
        if not self.debug:
            silent_stdout = io.StringIO()
            sys.stdout = sys.stderr = silent_stdout
            
        # create a GSAS-II project
        gpx = gsasii.G2Project(newgpx=f"{dir_name}/lead_sulphate.gpx")

        # add histograms
        for det in self.detectors:
            gpx.add_powder_histogram(det["data_file"], det["detector_file"])

        # add phases
        for phase in self.phases:
            gpx.add_phase(phase["phase_file"], phase["phase_label"],
                          histograms=gpx.histograms())

        # turn on background refinement
        args = {
                "Background": {
                    "no. coeffs" : 3,
                    "refine": True,
                }
        }
        for hist in gpx.histograms():
            hist.set_refinements(args)

        # refine
        gpx.do_refinements([{}])
        gpx.save(f"{dir_name}/step_1.gpx")
        
        # create a GSAS-II project
        gpx = gsasii.G2Project(f"{dir_name}/step_1.gpx")
        gpx.save(f"{dir_name}/step_2.gpx")

        # change lattice parameters
        for phase in gpx["Phases"].keys():

            # ignore data key
            if phase == "data":
                continue

            # handle PBSO4 phase
            elif phase == "PBSO4":
                cell = gpx["Phases"][phase]["General"]["Cell"]
                a, b, c = p
                t11, t22, t33 = cell[1] / a, cell[2] / b, cell[3] / c
                gpx["Phases"][phase]["General"]["Cell"][1:] = lattice.TransformCell(
                    cell[1:7], [[t11, 0.0, 0.0],
                                [0.0, t22, 0.0],
                                [0.0, 0.0, t33]])

            # otherwise raise error because refinement plan does not support this phase
            else:
                raise NotImplementedError("Refinement plan cannot handle phase {}".format(phase))

        # turn on unit cell refinement
        args = {
            "set": {
                "Cell" : True,
            }
        }

        # refine
        gpx.set_refinement(args)
        gpx.do_refinements([{}])
        
        # now restore stdout and stderr
        if not self.debug:
            sys.stdout = sys.__stdout__
            sys.stderr = sys.__stderr__

        # get minimization statistic
        stat = gpx["Covariance"]["data"]["Rvals"]["Rwp"]

        # print a message to follow the results
        print(f"Our R-factor is {stat} and it took {time.time() - t0}s to compute")

        return stat
# Out:
# GSAS-II binary directory: /Users/cmbiwer/anaconda3/envs/spotlight-gsas2/GSASII/bindist

# %% [markdown]
# ## An ensemble using only the cost function
#
# Below, we present an example of using an ensemble of optimizers in parallel with GSAS-II to find the global minimum.
# **Note, this will take awhile. It depends on the number of processors available on your machine.**
# We set the number of function calls to 50 to limit the amount of time it will take.

# %%
from mystic import tools
from mystic.solvers import BuckshotSolver
from mystic.solvers import NelderMeadSimplexSolver
from mystic.termination import VTR
from pathos.pools import ProcessPool as Pool

# set the ranges
target = [8.474, 5.394, 6.954]
lower_bounds = [x * 0.95 for x in target]
upper_bounds = [x * 1.05 for x in target]
    
# get number of parameters in model
ndim = len(target)
    
# set random seed so we can reproduce results
tools.random_seed(0)
    
# create a solver
solver = BuckshotSolver(dim=ndim, npts=8)
    
# set multi-processing pool
solver.SetMapper(Pool().map)
    
# since we have an search solver
# we specify what optimization algorithm to use within the search
# we tell the optimizer to not go more than 50 evaluations of our cost function
subsolver = NelderMeadSimplexSolver(ndim)
subsolver.SetEvaluationLimits(50, 50)
solver.SetNestedSolver(subsolver)
    
# set the range to search for all parameters
solver.SetStrictRanges(lower_bounds, upper_bounds)
    
# find the minimum
solver.Solve(CostFunction(ndim), VTR())
    
# print the best parameters
print(f"The best solution is {solver.bestSolution} with Rwp {solver.bestEnergy}")
print(f"The reference solutions is {target}")
ratios = [x / y for x, y in zip(target, solver.bestSolution)]
print(f"The ratios of to the reference values are {ratios}")
# Out:
# Our R-factor is 51.451971374756155 and it took 7.922705888748169s to compute
# Our R-factor is 50.417913808304995 and it took 8.017292022705078s to compute
# Our R-factor is 51.28232042340777 and it took 8.144327878952026s to compute
# Our R-factor is 51.091942862938346 and it took 8.279250860214233s to compute
# Our R-factor is 51.27628865991811 and it took 9.38934588432312s to compute
# Our R-factor is 50.08923603492271 and it took 9.453613042831421s to compute
# Our R-factor is 50.35337155042529 and it took 9.481461763381958s to compute
# Our R-factor is 50.81434198032311 and it took 10.025512218475342s to compute
# Our R-factor is 51.38764331916333 and it took 8.434493780136108s to compute
# Our R-factor is 51.20099807240431 and it took 9.807249069213867s to compute
# Our R-factor is 50.44817967359154 and it took 9.921422719955444s to compute
# Our R-factor is 50.95111290919368 and it took 10.085067987442017s to compute
# Our R-factor is 51.1257501038701 and it took 9.93289589881897s to compute
# Our R-factor is 50.99723479537669 and it took 9.916821002960205s to compute
# Our R-factor is 51.1124148601718 and it took 10.0743248462677s to compute
# Our R-factor is 50.9823749860382 and it took 10.38204312324524s to compute
# Our R-factor is 50.83682048494078 and it took 10.205211877822876s to compute
# Our R-factor is 51.2034294069999 and it took 8.97409200668335s to compute
# Our R-factor is 50.389647149397774 and it took 10.520982027053833s to compute
# Our R-factor is 50.6654078961978 and it took 10.681488752365112s to compute
# Our R-factor is 51.15590608708599 and it took 10.402451992034912s to compute
# Our R-factor is 50.92611408438113 and it took 10.56220006942749s to compute
# Our R-factor is 51.24946314796024 and it took 10.445168256759644s to compute
# Our R-factor is 41.741654386122576 and it took 10.735933065414429s to compute
# Our R-factor is 51.125968997282314 and it took 9.77748703956604s to compute
# Our R-factor is 50.46083480934407 and it took 9.875218868255615s to compute
# Our R-factor is 51.09441399798872 and it took 8.379135847091675s to compute
# Our R-factor is 50.497143730052215 and it took 9.816709280014038s to compute
# Our R-factor is 48.58861425316758 and it took 10.164114952087402s to compute
# Our R-factor is 51.20248992689357 and it took 9.75884199142456s to compute
# Our R-factor is 49.19412815023905 and it took 9.894005060195923s to compute
# Our R-factor is 50.37790706751931 and it took 10.036686897277832s to compute
# Our R-factor is 51.45165059169662 and it took 8.269470930099487s to compute
# Our R-factor is 50.57967860950032 and it took 10.020257949829102s to compute
# Our R-factor is 51.31470259818279 and it took 8.642888069152832s to compute
# Our R-factor is 50.475418592812595 and it took 10.185289144515991s to compute
# Our R-factor is 50.789266255759166 and it took 10.17238712310791s to compute
# Our R-factor is 50.66594121236802 and it took 10.282721996307373s to compute
# Our R-factor is 48.76644162181453 and it took 10.551836967468262s to compute
# Our R-factor is 49.97506220259576 and it took 10.70930004119873s to compute
# Our R-factor is 51.40957173284818 and it took 8.90704894065857s to compute
# Our R-factor is 50.89960166435209 and it took 10.770054817199707s to compute
# Our R-factor is 51.00297593233655 and it took 9.096890926361084s to compute
# Our R-factor is 51.059611975736516 and it took 10.55167007446289s to compute
# Our R-factor is 47.56916764050982 and it took 10.990826845169067s to compute
# Our R-factor is 50.18532610091735 and it took 10.791611909866333s to compute
# Our R-factor is 50.837240122016524 and it took 9.389055013656616s to compute
# Our R-factor is 50.231608591359326 and it took 11.185740947723389s to compute
# Our R-factor is 51.19834701563002 and it took 10.658488988876343s to compute
# Our R-factor is 50.715344477100125 and it took 10.511384963989258s to compute
# Our R-factor is 50.52498786305652 and it took 10.606613874435425s to compute
# Our R-factor is 50.97331984643797 and it took 10.491922855377197s to compute
# Our R-factor is 50.74371876758927 and it took 9.459589004516602s to compute
# Our R-factor is 51.04275297477715 and it took 11.123373746871948s to compute
# Our R-factor is 50.164069480909454 and it took 10.888462781906128s to compute
# Our R-factor is 50.310175705780615 and it took 10.729987859725952s to compute
# Our R-factor is 51.43955708392615 and it took 8.867042064666748s to compute
# Our R-factor is 50.38394132614543 and it took 10.35812497138977s to compute
# Our R-factor is 50.46692032653384 and it took 10.220067739486694s to compute
# Our R-factor is 51.10763077055588 and it took 10.205134868621826s to compute
# Our R-factor is 49.26917258716222 and it took 10.501848697662354s to compute
# Our R-factor is 50.372543507609244 and it took 10.4339919090271s to compute
# Our R-factor is 50.11280003057338 and it took 10.439882040023804s to compute
# Our R-factor is 50.85846944150675 and it took 10.74583911895752s to compute
# Our R-factor is 51.06005392440138 and it took 10.030611038208008s to compute
# Our R-factor is 51.2034294069999 and it took 8.678936243057251s to compute
# Our R-factor is 51.33798382359558 and it took 8.640381097793579s to compute
# Our R-factor is 50.61230357090256 and it took 10.16265320777893s to compute
# Our R-factor is 50.920441590100815 and it took 10.399681806564331s to compute
# Our R-factor is 50.748280205215934 and it took 10.121737003326416s to compute
# Our R-factor is 50.96001094633246 and it took 10.078434944152832s to compute
# Our R-factor is 51.34252734258968 and it took 9.813887119293213s to compute
# Our R-factor is 49.68279264996758 and it took 10.296857833862305s to compute
# Our R-factor is 50.46541263556501 and it took 9.999797821044922s to compute
# Our R-factor is 51.09837245618365 and it took 9.895886898040771s to compute
# Our R-factor is 50.37190500952723 and it took 10.075186014175415s to compute
# Our R-factor is 47.79568378718114 and it took 10.198119878768921s to compute
# Our R-factor is 49.8961064936403 and it took 10.11998701095581s to compute
# Our R-factor is 51.20195298918625 and it took 9.908117055892944s to compute
# Our R-factor is 50.03971477674073 and it took 10.278770923614502s to compute
# Our R-factor is 49.27375261852594 and it took 10.337630033493042s to compute
# Our R-factor is 51.325160860083784 and it took 8.552639961242676s to compute
# Our R-factor is 50.62082277033863 and it took 9.985766887664795s to compute
# Our R-factor is 50.92510495620287 and it took 8.682423114776611s to compute
# Our R-factor is 47.23314490811743 and it took 10.738449335098267s to compute
# Our R-factor is 51.184829563871624 and it took 8.880871057510376s to compute
# Our R-factor is 47.49882377689143 and it took 10.683964967727661s to compute
# Our R-factor is 49.764925123051945 and it took 10.703817129135132s to compute
# Our R-factor is 49.31712519335269 and it took 10.727458238601685s to compute
# Our R-factor is 51.10489175057027 and it took 10.456876039505005s to compute
# Our R-factor is 50.52010108648911 and it took 10.684861898422241s to compute
# Our R-factor is 50.44176281888182 and it took 10.649354934692383s to compute
# Our R-factor is 51.34656733042762 and it took 8.700608968734741s to compute
# Our R-factor is 50.54089384295267 and it took 10.718613862991333s to compute
# Our R-factor is 51.14556488447417 and it took 10.363054037094116s to compute
# Our R-factor is 49.23870397317428 and it took 10.364212989807129s to compute
# Our R-factor is 48.57951580856511 and it took 10.349469900131226s to compute
# Our R-factor is 50.905778351347486 and it took 8.752398014068604s to compute
# Our R-factor is 51.045156348536416 and it took 10.217574119567871s to compute
# Our R-factor is 50.397150297309345 and it took 10.352388143539429s to compute
# Our R-factor is 51.18524042028485 and it took 10.327361106872559s to compute
# Our R-factor is 50.57711468260852 and it took 9.39541506767273s to compute
# Our R-factor is 49.51692649732765 and it took 11.118013143539429s to compute
# Our R-factor is 48.49231768517496 and it took 10.935806035995483s to compute
# Our R-factor is 49.54957138634197 and it took 11.099185943603516s to compute
# Our R-factor is 50.369174257615704 and it took 10.932441234588623s to compute
# Our R-factor is 51.2441349745108 and it took 10.79810905456543s to compute
# Our R-factor is 50.457384050197426 and it took 10.743052005767822s to compute
# Our R-factor is 51.184246740078166 and it took 10.344189167022705s to compute
# Our R-factor is 49.84018592898947 and it took 10.705356121063232s to compute
# Our R-factor is 44.583625243518874 and it took 10.547171831130981s to compute
# Our R-factor is 49.611342583160365 and it took 10.390001058578491s to compute
# Our R-factor is 44.53538549078123 and it took 10.523083925247192s to compute
# Our R-factor is 50.348980489549454 and it took 10.244394063949585s to compute
# Our R-factor is 51.05277556571058 and it took 10.171290874481201s to compute
# Our R-factor is 50.384022565778416 and it took 10.343785047531128s to compute
# Our R-factor is 51.19381381594389 and it took 8.883059978485107s to compute
# Our R-factor is 47.73738144908092 and it took 10.791626930236816s to compute
# Our R-factor is 50.38059562123903 and it took 10.732862949371338s to compute
# Our R-factor is 48.44113645286578 and it took 11.011083126068115s to compute
# Our R-factor is 49.70164229665934 and it took 10.983027219772339s to compute
# Our R-factor is 50.17629551898678 and it took 10.611413955688477s to compute
# Our R-factor is 51.05610461709749 and it took 10.566885232925415s to compute
# Our R-factor is 51.18564835558549 and it took 9.00576114654541s to compute
# Our R-factor is 50.492858491518845 and it took 10.542400121688843s to compute
# Our R-factor is 39.72117587317019 and it took 10.81750202178955s to compute
# Our R-factor is 40.97743037571086 and it took 10.698469161987305s to compute
# Our R-factor is 48.64856236999502 and it took 10.327988147735596s to compute
# Our R-factor is 51.188510933424055 and it took 8.479676246643066s to compute
# Our R-factor is 31.34774128232599 and it took 10.381498098373413s to compute
# Our R-factor is 50.62821755696416 and it took 9.943318605422974s to compute
# Our R-factor is 50.97660914847519 and it took 10.073646068572998s to compute
# Our R-factor is 50.353776896954294 and it took 10.058204174041748s to compute
# Our R-factor is 49.52956298054862 and it took 8.872211217880249s to compute
# Our R-factor is 45.54707599582501 and it took 10.396492004394531s to compute
# Our R-factor is 51.18662224585123 and it took 8.65332818031311s to compute
# Our R-factor is 49.264792712263855 and it took 10.4355149269104s to compute
# Our R-factor is 49.03495691342985 and it took 10.653945922851562s to compute
# Our R-factor is 50.11693012801655 and it took 10.30081295967102s to compute
# Our R-factor is 51.14385362384773 and it took 10.378778219223022s to compute
# Our R-factor is 50.74853508249596 and it took 10.48341703414917s to compute
# Our R-factor is 37.12763051616232 and it took 10.568994760513306s to compute
# Our R-factor is 48.98103009901293 and it took 10.53276801109314s to compute
# Our R-factor is 51.12500466163383 and it took 10.091829061508179s to compute
# Our R-factor is 48.38675574891172 and it took 10.43808102607727s to compute
# Our R-factor is 50.454994004053034 and it took 10.349533319473267s to compute
# Our R-factor is 47.37046518645871 and it took 10.662704706192017s to compute
# Our R-factor is 51.08635165999694 and it took 10.328588008880615s to compute
# Our R-factor is 50.363474852976864 and it took 8.9779212474823s to compute
# Our R-factor is 47.518826644999834 and it took 10.278551816940308s to compute
# Our R-factor is 46.5937787161495 and it took 10.485064029693604s to compute
# Our R-factor is 50.79170296226111 and it took 9.983902931213379s to compute
# Our R-factor is 49.105184091141666 and it took 10.325523853302002s to compute
# Our R-factor is 50.18796588171388 and it took 10.039502143859863s to compute
# Our R-factor is 45.10735404020059 and it took 10.263418197631836s to compute
# Our R-factor is 50.972566872518165 and it took 9.91340708732605s to compute
# Our R-factor is 50.37122781223646 and it took 10.051882982254028s to compute
# Our R-factor is 43.070522779592345 and it took 10.361461877822876s to compute
# Our R-factor is 49.040592888908876 and it took 10.36161994934082s to compute
# Our R-factor is 50.81023199386486 and it took 9.870847940444946s to compute
# Our R-factor is 50.24422450436944 and it took 8.551439046859741s to compute
# Our R-factor is 47.892117097316444 and it took 10.247720956802368s to compute
# Our R-factor is 51.06255306298725 and it took 9.862884998321533s to compute
# Our R-factor is 34.43602596063249 and it took 10.218490839004517s to compute
# Our R-factor is 50.385319605653 and it took 10.059789180755615s to compute
# Our R-factor is 40.052236439568105 and it took 10.338038206100464s to compute
# Our R-factor is 50.81332869817331 and it took 9.838309288024902s to compute
# Our R-factor is 46.636105985412804 and it took 10.253199815750122s to compute
# Our R-factor is 50.17125922173955 and it took 9.89949893951416s to compute
# Our R-factor is 51.06202366985501 and it took 8.513200044631958s to compute
# Our R-factor is 49.64917211310989 and it took 10.354957103729248s to compute
# Our R-factor is 50.357238501809576 and it took 10.015347957611084s to compute
# Our R-factor is 40.52693053630595 and it took 10.406554222106934s to compute
# Our R-factor is 50.77381837003483 and it took 9.82146406173706s to compute
# Our R-factor is 37.98171192873308 and it took 10.273495197296143s to compute
# Our R-factor is 50.94385725826016 and it took 8.530498027801514s to compute
# Our R-factor is 50.57852888215004 and it took 10.418300151824951s to compute
# Our R-factor is 50.156756048785155 and it took 9.836695194244385s to compute
# Our R-factor is 47.923104627853995 and it took 10.30429220199585s to compute
# Our R-factor is 50.37439925409145 and it took 10.342735052108765s to compute
# Our R-factor is 43.37009576751933 and it took 10.53646183013916s to compute
# Our R-factor is 50.89108738164486 and it took 9.082820892333984s to compute
# Our R-factor is 50.75775687087213 and it took 10.385524034500122s to compute
# Our R-factor is 41.453113893480406 and it took 10.846374034881592s to compute
# Our R-factor is 45.41823902303183 and it took 10.748380899429321s to compute
# Our R-factor is 50.11816805862408 and it took 10.516499996185303s to compute
# Our R-factor is 42.92931661352286 and it took 10.614914655685425s to compute
# Our R-factor is 50.35385531823867 and it took 10.256123065948486s to compute
# Our R-factor is 31.18371350018935 and it took 10.498226881027222s to compute
# Our R-factor is 50.91531763103813 and it took 10.017187118530273s to compute
# Our R-factor is 50.814507219684714 and it took 9.822985887527466s to compute
# Our R-factor is 33.74401088250792 and it took 10.40044093132019s to compute
# Our R-factor is 50.084315434795926 and it took 9.937234163284302s to compute
# Our R-factor is 41.39410192230955 and it took 10.375152111053467s to compute
# Our R-factor is 40.91766322208945 and it took 10.263399839401245s to compute
# Our R-factor is 50.40001059692333 and it took 10.04689884185791s to compute
# Our R-factor is 45.61107849373328 and it took 10.285758972167969s to compute
# Our R-factor is 50.907634497166775 and it took 9.89804482460022s to compute
# Our R-factor is 50.76175873626494 and it took 9.765147924423218s to compute
# Our R-factor is 38.63433996467267 and it took 10.177271127700806s to compute
# Our R-factor is 50.07497735709073 and it took 9.905917882919312s to compute
# Our R-factor is 34.03169268863946 and it took 10.291182041168213s to compute
# Our R-factor is 50.35410080868199 and it took 8.66975212097168s to compute
# Our R-factor is 41.67143553880698 and it took 10.31547498703003s to compute
# Our R-factor is 26.566900453239178 and it took 10.388882160186768s to compute
# Our R-factor is 50.48333862190619 and it took 10.260403871536255s to compute
# Our R-factor is 50.75993227479058 and it took 10.156702041625977s to compute
# Our R-factor is 50.18755451783472 and it took 10.44739294052124s to compute
# Our R-factor is 32.39373083282412 and it took 10.716403007507324s to compute
# Our R-factor is 38.390835688629885 and it took 10.886193990707397s to compute
# Our R-factor is 50.35680824170294 and it took 10.724536895751953s to compute
# Our R-factor is 48.577436918310056 and it took 11.051904201507568s to compute
# Our R-factor is 29.889874378772074 and it took 11.11922812461853s to compute
# Our R-factor is 50.31727078078173 and it took 10.635627031326294s to compute
# Our R-factor is 50.80835953890919 and it took 10.579981088638306s to compute
# Our R-factor is 50.106368044993744 and it took 10.522171974182129s to compute
# Our R-factor is 50.35655895962484 and it took 9.158554792404175s to compute
# Our R-factor is 39.40392916405938 and it took 10.84781002998352s to compute
# Our R-factor is 38.62335999043058 and it took 10.964709997177124s to compute
# Our R-factor is 47.089041438785785 and it took 10.57166600227356s to compute
# Our R-factor is 43.81285977119655 and it took 10.729084968566895s to compute
# Our R-factor is 50.59827953622773 and it took 10.262457132339478s to compute
# Our R-factor is 50.77673976295824 and it took 10.168798923492432s to compute
# Our R-factor is 50.07192090163194 and it took 8.618048191070557s to compute
# Our R-factor is 50.353212163624846 and it took 10.134520769119263s to compute
# Our R-factor is 29.147105289861486 and it took 10.425173044204712s to compute
# Our R-factor is 39.24960376892473 and it took 10.426088809967041s to compute
# Our R-factor is 41.72869245307233 and it took 10.374513864517212s to compute
# Our R-factor is 27.830666828565054 and it took 10.361902952194214s to compute
# Our R-factor is 50.757860166529575 and it took 10.17048692703247s to compute
# Our R-factor is 50.68441872109506 and it took 10.367486953735352s to compute
# Our R-factor is 50.11441812084579 and it took 10.302081823348999s to compute
# Our R-factor is 50.357238501809576 and it took 10.526009798049927s to compute
# Our R-factor is 42.810977818735644 and it took 10.972437858581543s to compute
# Our R-factor is 32.77871324570473 and it took 10.864498853683472s to compute
# Our R-factor is 48.6882569871068 and it took 10.958647966384888s to compute
# Our R-factor is 31.253125380422595 and it took 10.9305260181427s to compute
# Our R-factor is 51.04492945792383 and it took 8.997183084487915s to compute
# Our R-factor is 50.758096730993074 and it took 10.275415182113647s to compute
# Our R-factor is 50.078770232780926 and it took 10.364781141281128s to compute
# Our R-factor is 50.36621427887042 and it took 10.701371192932129s to compute
# Our R-factor is 28.222534818177657 and it took 10.883971929550171s to compute
# Our R-factor is 45.85770035666167 and it took 10.872278690338135s to compute
# Our R-factor is 39.36003790999968 and it took 10.722902059555054s to compute
# Our R-factor is 26.210381587046 and it took 10.89637279510498s to compute
# Our R-factor is 50.78702422251871 and it took 10.554183959960938s to compute
# Our R-factor is 50.75791363973803 and it took 10.459413051605225s to compute
# Our R-factor is 50.092856319767876 and it took 10.584649801254272s to compute
# Our R-factor is 50.3546733619408 and it took 8.853013753890991s to compute
# Our R-factor is 42.23305060045403 and it took 10.382324934005737s to compute
# Our R-factor is 41.984880503021216 and it took 10.532768964767456s to compute
# Our R-factor is 48.04530320371338 and it took 10.398268222808838s to compute
# Our R-factor is 32.76321959428025 and it took 10.373401880264282s to compute
# Our R-factor is 50.83663201123908 and it took 10.147639036178589s to compute
# Our R-factor is 50.75769326789913 and it took 9.922178030014038s to compute
# Our R-factor is 50.07952513292864 and it took 9.94905424118042s to compute
# Our R-factor is 50.352701085934946 and it took 10.03203296661377s to compute
# Our R-factor is 27.728559635010097 and it took 10.124526977539062s to compute
# Our R-factor is 30.35443855337171 and it took 10.158079147338867s to compute
# Our R-factor is 38.91548832908706 and it took 9.97654104232788s to compute
# Our R-factor is 27.038312104051208 and it took 9.773526906967163s to compute
# Our R-factor is 50.499265289570076 and it took 9.517446994781494s to compute
# Our R-factor is 50.07184442280166 and it took 9.371530055999756s to compute
# Our R-factor is 50.35296175366207 and it took 9.47995400428772s to compute
# Our R-factor is 26.299481115462974 and it took 9.841674089431763s to compute
# Our R-factor is 32.91626943801119 and it took 9.852939128875732s to compute
# Our R-factor is 37.161901100454095 and it took 9.90663194656372s to compute
# Our R-factor is 50.47556195968518 and it took 9.674030065536499s to compute
# Our R-factor is 31.92412323454601 and it took 10.09642505645752s to compute
# Our R-factor is 50.356011304537574 and it took 8.489552021026611s to compute
# Our R-factor is 50.106368044993744 and it took 9.858083963394165s to compute
# Our R-factor is 34.015020369916975 and it took 10.213620901107788s to compute
# Our R-factor is 42.376191949500765 and it took 10.190315008163452s to compute
# Our R-factor is 42.987650180927325 and it took 10.092888116836548s to compute
# Our R-factor is 50.3681862889587 and it took 9.658674955368042s to compute
# Our R-factor is 50.08760013654564 and it took 8.246235132217407s to compute
# Our R-factor is 26.381032236316116 and it took 9.96720838546753s to compute
# Our R-factor is 50.35528329168791 and it took 9.572556018829346s to compute
# Our R-factor is 27.109836471704433 and it took 9.60987114906311s to compute
# Our R-factor is 26.966436653156588 and it took 9.623719215393066s to compute
# Our R-factor is 35.35439398721708 and it took 9.602323055267334s to compute
# Our R-factor is 50.23072768495934 and it took 9.359890222549438s to compute
# Our R-factor is 50.072338360650704 and it took 9.368271112442017s to compute
# Our R-factor is 27.378376914659274 and it took 9.77711009979248s to compute
# Our R-factor is 50.35357523038259 and it took 9.483088970184326s to compute
# Our R-factor is 34.69843223418834 and it took 9.978234767913818s to compute
# Our R-factor is 41.253017868161365 and it took 10.016870737075806s to compute
# Our R-factor is 40.532564104143546 and it took 9.79968810081482s to compute
# Our R-factor is 50.174338615431104 and it took 9.687177896499634s to compute
# Our R-factor is 50.07814680268673 and it took 9.616271257400513s to compute
# Our R-factor is 26.04994095882137 and it took 9.959516048431396s to compute
# Our R-factor is 50.35259124481237 and it took 9.684362173080444s to compute
# Our R-factor is 26.89463650195007 and it took 9.662610054016113s to compute
# Our R-factor is 27.696042085542842 and it took 9.6218900680542s to compute
# Our R-factor is 40.90607351318388 and it took 9.612915992736816s to compute
# Our R-factor is 50.255682576560964 and it took 9.307348012924194s to compute
# Our R-factor is 50.356011304537574 and it took 7.935244083404541s to compute
# Our R-factor is 50.07015760428967 and it took 9.236654043197632s to compute
# Our R-factor is 32.27237071786678 and it took 9.602852821350098s to compute
# Our R-factor is 27.106617025501635 and it took 9.47835397720337s to compute
# Our R-factor is 29.61470143369039 and it took 9.458343267440796s to compute
# Our R-factor is 35.66739410809024 and it took 9.384047031402588s to compute
# Our R-factor is 50.545494907547784 and it took 9.199261903762817s to compute
# Our R-factor is 50.35264195072601 and it took 9.234216928482056s to compute
# Our R-factor is 50.071060156055815 and it took 9.20716905593872s to compute
# Our R-factor is 25.50526070687337 and it took 9.446073770523071s to compute
# Our R-factor is 25.518012695741483 and it took 9.237441062927246s to compute
# Our R-factor is 41.166289081833625 and it took 9.161961078643799s to compute
# Our R-factor is 50.237965759941424 and it took 8.756486177444458s to compute
# Our R-factor is 36.336646255705176 and it took 9.030112981796265s to compute
# Our R-factor is 50.35243881791405 and it took 8.829811096191406s to compute
# Our R-factor is 26.507237069948957 and it took 9.027583122253418s to compute
# Our R-factor is 26.554443203847267 and it took 9.040642023086548s to compute
# Our R-factor is 26.42747825360602 and it took 8.997760772705078s to compute
# Our R-factor is 50.15167900185704 and it took 8.728856801986694s to compute
# Our R-factor is 45.206255898864164 and it took 8.924728155136108s to compute
# Our R-factor is 50.35303841247304 and it took 8.743982076644897s to compute
# Our R-factor is 25.875329988026408 and it took 8.967442989349365s to compute
# Our R-factor is 29.14046299571301 and it took 8.918919801712036s to compute
# Our R-factor is 50.5847918309516 and it took 7.443347930908203s to compute
# Our R-factor is 32.91480220455673 and it took 8.872719049453735s to compute
# Our R-factor is 33.53820283578147 and it took 8.800538778305054s to compute
# Our R-factor is 25.765329610738696 and it took 8.588640928268433s to compute
# Our R-factor is 25.745394933101178 and it took 8.140196800231934s to compute
# Our R-factor is 27.25572778791362 and it took 8.057861804962158s to compute
# Our R-factor is 37.924006654319406 and it took 8.009179830551147s to compute
# Our R-factor is 25.48444701169479 and it took 8.128000974655151s to compute
# Our R-factor is 28.34371407427188 and it took 8.226928949356079s to compute
# Our R-factor is 28.106358427489724 and it took 8.184787034988403s to compute
# Our R-factor is 34.10977683189295 and it took 8.145719051361084s to compute
# Our R-factor is 25.732345207616085 and it took 8.058310985565186s to compute
# Our R-factor is 25.872552127983177 and it took 7.865749835968018s to compute
# Our R-factor is 26.894328641738678 and it took 7.8460609912872314s to compute
# Our R-factor is 25.92319197596836 and it took 7.688520193099976s to compute
# Our R-factor is 26.808873930535565 and it took 7.60550332069397s to compute
# Our R-factor is 25.961739737033895 and it took 7.623624801635742s to compute
# Our R-factor is 25.51093837395767 and it took 7.597993850708008s to compute
# Our R-factor is 25.53962500031566 and it took 7.649769067764282s to compute
# Our R-factor is 28.578667610013493 and it took 7.615344047546387s to compute
# Our R-factor is 25.65707363605166 and it took 7.5529820919036865s to compute
# Our R-factor is 27.308156297190955 and it took 7.129370212554932s to compute
# Our R-factor is 25.50202067709244 and it took 7.11699104309082s to compute
# Our R-factor is 26.296137371587875 and it took 7.2504260540008545s to compute
# Our R-factor is 25.665891264899177 and it took 6.925315856933594s to compute
# Our R-factor is 25.4758672909568 and it took 6.071974039077759s to compute
# The best solution is [8.47700749 5.39825091 6.95398785] with Rwp 25.4758672909568
# The reference solutions is [8.474, 5.394, 6.954]
# The ratios of to the reference values are [0.9996452182518525, 0.9992125391105748, 1.0000017469857228]

# %% [markdown]
# This concludes the example using GSAS-II.
